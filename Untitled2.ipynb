# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# Load dataset
file_path = "gameandgrade.csv"  
# Change this if needed
df = pd.read_csv(file_path)
# Remove any extra dots and non-numeric characters
df['Grade'] = df['Grade'].astype(str).str.replace(r'[^0-9.]', '', regex=True)  # Keep only numbers and dots

# Handle cases where there are multiple dots (e.g., '92..00')
df['Grade'] = df['Grade'].str.replace(r'\.{2,}', '.', regex=True)  # Replace multiple dots with a single dot

# Convert to float
df['Grade'] = pd.to_numeric(df['Grade'], errors='coerce')  # Convert to float, set errors to NaN if invalid

# Check if there are still any NaN values after conversion
print(df['Grade'].isna().sum(), "invalid values converted to NaN")
print(df['Grade'].dtype)  # Should print float64 or int64
# Out:
# 0 invalid values converted to NaN
# float64

# %%
df
# Out:
#      Sex  School Code  Playing Years  Playing Often  Playing Hours  \
# 0      0            1              1              2              1
# 1      1            1              1              3              1
# 2      0            1              0              0              0
# 3      0            1              3              5              1
# 4      1            1              1              1              2
# ..   ...          ...            ...            ...            ...
# 765    1            2              1              2              4
# 766    1            9              2              5              1
# 767    0            4              2              1              3
# 768    0            4              2              1              3
# 769    0            9              2              5              2
#
#      Playing Games  Parent Revenue  Father Education  Mother Education  Grade
# 0                1               4                 4                 5   77.5
# ...

# %%
# Basic info and summary
print("Dataset Information:\n")
df.info()
print("\nSummary Statistics:\n", df.describe())
# Out:
# Dataset Information:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 770 entries, 0 to 769
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Sex               770 non-null    int64
#  1   School Code       770 non-null    int64
#  2   Playing Years     770 non-null    int64
#  3   Playing Often     770 non-null    int64
#  4   Playing Hours     770 non-null    int64
#  5   Playing Games     770 non-null    int64
#  6   Parent Revenue    770 non-null    int64
#  7   Father Education  770 non-null    int64
#  8   Mother Education  770 non-null    int64
#  9   Grade             770 non-null    float64
# dtypes: float64(1), int64(9)
# memory usage: 60.3 KB
#
# Summary Statistics:
#                Sex  School Code  Playing Years  Playing Often  Playing Hours  \
# count  770.000000   770.000000     770.000000     770.000000     770.000000
# ...

# %%
missing_values = df.isnull().sum()
print('Missing values in each column:')
print(missing_values)

# In this dataset, if there are missing values, we perform a simple imputation or drop rows based on the extent of missingness.
if missing_values.sum() > 0:
    # Given the small dataset size in many Kaggle competitions, dropping may be acceptable
    df = df.dropna()
    print('Dropped rows with missing values')

# Check data types
print('\nData Types:')
print(df.dtypes)

# Convert the Grade column to a categorical type (if it is not already)
df['Grade'] = df['Grade'].astype('category')

print('\nUnique grades:', df['Grade'].unique())
# Out:
# Missing values in each column:
# Sex                 0
# School Code         0
# Playing Years       0
# Playing Often       0
# Playing Hours       0
# Playing Games       0
# Parent Revenue      0
# Father Education    0
# Mother Education    0
# Grade               0
# dtype: int64
#
# Data Types:
# Sex                   int64
# School Code           int64
# Playing Years         int64
# Playing Often         int64
# Playing Hours         int64
# Playing Games         int64
# Parent Revenue        int64
# Father Education      int64
# Mother Education      int64
# Grade               float64
# dtype: object
#
# Unique grades: [77.5, 83.0, 80.0, 45.0, 85.0, ..., 82.20, 81.00, 55.30, 64.75, 45.50]
# Length: 103
# Categories (103, float64): [33.00, 36.50, 40.00, 42.35, ..., 98.0, 98.5, 99.0, 100.0]

# %%
# Histogram of numeric columns
numeric_columns = ['Sex', 'School Code', 'Playing Years', 'Playing Often', 'Playing Hours', 'Playing Games', 'Parent Revenue', 'Father Education', 'Mother Education']
for col in numeric_columns:
    plt.figure(figsize=(8, 4))
    sns.histplot(df[col], kde=True, bins=20, color='skyblue')
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.tight_layout()
    plt.show()
    

# Count plot for the Grade distribution
plt.figure(figsize=(8, 4))
sns.countplot(x='Grade', data=df, palette='viridis')
plt.title('Distribution of Grades')
plt.xlabel('Grade')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# Group by '' and calculate the mean of 'Grade'
mother_edu_avg_grade = df.groupby('Mother Education', as_index=False)['Grade'].mean()

# Plot the bar graph
plt.figure(figsize=(8, 4))
sns.barplot(x='Mother Education', y='Grade', data=mother_edu_avg_grade, palette='Purples')
plt.title("Mean Grade vs Mother's Education")
plt.xlabel("Mother's Education Level")
plt.ylabel("Mean Grade")
plt.xticks(rotation=0)  # Rotate x-axis labels if needed
plt.tight_layout()
plt.show()

# %%
# Group by '' and calculate the mean of 'Grade'
mother_edu_avg_grade = df.groupby('Parent Revenue', as_index=False)['Grade'].mean()

# Plot the bar graph
plt.figure(figsize=(8, 4))
sns.barplot(x='Parent Revenue', y='Grade', data=mother_edu_avg_grade, palette='Purples')
plt.title("Mean Grade vs Parent Revenue")
plt.xlabel("Parent Revenue")
plt.ylabel("Mean Grade")
plt.xticks(rotation=0)  # Rotate x-axis labels if needed
plt.tight_layout()
plt.show()

# %%
# Group by '' and calculate the mean of 'Grade'
mother_edu_avg_grade = df.groupby('Playing Often', as_index=False)['Grade'].mean()

# Plot the bar graph
plt.figure(figsize=(8, 4))
sns.barplot(x='Playing Often', y='Grade', data=mother_edu_avg_grade, palette='Purples')
plt.title("Mean Grade vs Physical activity ")
plt.xlabel("how often they play")
plt.ylabel("Mean Grade")
plt.xticks(rotation=0)  # Rotate x-axis labels if needed
plt.tight_layout()
plt.show()
"""
the following plot shows that the students who play more often have on an average more grades than those who play less, showing importance of
playing games.
"""

# %%
# Group by '' and calculate the mean of 'Grade'
mother_edu_avg_grade = df.groupby('Playing Hours', as_index=False)['Grade'].mean()

# Plot the bar graph
plt.figure(figsize=(8, 4))
sns.barplot(x='Playing Hours', y='Grade', data=mother_edu_avg_grade, palette='Purples')
plt.title("Mean Grade vs how much they play ")
plt.xlabel("how much they play")
plt.ylabel("Mean Grade")
plt.xticks(rotation=0)  # Rotate x-axis labels if needed
plt.tight_layout()
plt.show()
"""
the following graph shows the average performance of students depending on their playing hours
the performance decreases the more they play.
"""

# %%
# Group by '' and calculate the mean of 'Grade'
mother_edu_avg_grade = df.groupby('Playing Years', as_index=False)['Grade'].mean()

# Plot the bar graph
plt.figure(figsize=(8, 4))
sns.barplot(x='Playing Years', y='Grade', data=mother_edu_avg_grade, palette='Purples')
plt.title("Mean Grade vs How long they have been playing ")
plt.xlabel("how long they have been playing")
plt.ylabel("Mean Grade")
plt.xticks(rotation=0)  # Rotate x-axis labels if needed
plt.tight_layout()
plt.show()
"""
the following curve shows the dependance of how long they have been playing and mean grade,there is no trend in this curve, showing that 
performance doesn't depend on playing.
"""

# %%
# Group by '' and calculate the mean of 'Grade'
mother_edu_avg_grade = df.groupby('School Code', as_index=False)['Grade'].mean()

# Plot the bar graph
plt.figure(figsize=(8, 4))
sns.barplot(x='School Code', y='Grade', data=mother_edu_avg_grade, palette='Purples')
plt.title("Mean Grade vs which school they belong to")
plt.xlabel("School code")
plt.ylabel("Mean Grade")
plt.xticks(rotation=0)  # Rotate x-axis labels if needed
plt.tight_layout()
plt.show()
"""
the following graph shows which average performance of schools
school 6 and 7 perform the best followed by 5,9 ...
"""

# %%
# Select only numeric columns for correlation
numeric_df = df.select_dtypes(include=[np.number])

if numeric_df.shape[1] >= 4:
    plt.figure(figsize=(10, 8))
    corr = numeric_df.corr()
    sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
    plt.title('Numeric Features Correlation Heatmap')
    plt.tight_layout()
    plt.show()
else:
    print('Not enough numeric features to create a correlation heatmap.')

"""
following heat map shows the interdependance of variables on each other
the gender and school code are categorical variables so they do not have any corellation with other variables
"""
